# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../'))

import numpy as np
import matplotlib.pyplot as plt

import astropy.units as u
import poliastro 

import CtllDes 
from CtllDes.core import ctll, satellite

from poliastro.bodies import Earth

sat = satellite.Sat.from_vectors([8000,0,0]*u.km,
                       [0,5,2.5]*u.km/u.s,
                      attractor=Earth)
# Out:
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]

# %%
from CtllDes.targets.targets import Target
tgt = Target(0,0)

# %%
from CtllDes.requests.comm import default_comm_data

# %%
default_comm_data(sat,tgt,5,dt=5,J2=True)
# Out:
# /home/vancii/Documents/Instituto Balseiro/6to semestre/pi/CtllDes/venv/lib/python3.8/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in arccos
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
#                                                       r  \
# 0                           [8000.0 km, 0.0 km, 0.0 km]
# 1     [7999.921619271596 km, 24.999634838996215 km, ...
# 2     [7999.687459622702 km, 49.998886942421954 km, ...
# 3     [7999.297511988847 km, 74.99726135940125 km, 3...
# 4     [7998.7517673055745 km, 99.99426313905813 km, ...
# ...                                                 ...
# 5328  [-1332.245186552752 km, 6303.0169176382105 km,...
# 5329  [-1360.0507077478635 km, 6284.44628426699 km, ...
# 5330  [-1387.8058822346331 km, 6265.641144660979 km,...
# 5331  [-1415.5093780499421 km, 6246.600735756619 km,...
# 5332  [-1443.1596887945132 km, 6227.324288732081 km,...
#
# ...
